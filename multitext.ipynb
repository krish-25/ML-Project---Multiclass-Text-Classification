# %%
#Importing necessary libraries
import pandas as pd
import string 
import nltk
import multiprocessing

from gensim.models import Word2Vec
from time import time
from time import time  # To time our operations
from collections import defaultdict  # For word frequency
from gensim.models import KeyedVectors

import logging  # Setting up the loggings to monitor gensim
logging.basicConfig(format="%(levelname)s - %(asctime)s: %(message)s", datefmt= '%H:%M:%S', level=logging.INFO)

# %%
#Importing dataset file- csv format
df = pd.read_csv("./Desktop/BBC News Train.csv")
df
# Out:
#       ArticleId                                               Text  \
# 0          1833  worldcom ex-boss launches defence lawyers defe...
# 1           154  german business confidence slides german busin...
# 2          1101  bbc poll indicates economic gloom citizens in ...
# 3          1976  lifestyle  governs mobile choice  faster  bett...
# 4           917  enron bosses in $168m payout eighteen former e...
# ...         ...                                                ...
# 1485        857  double eviction from big brother model caprice...
# 1486        325  dj double act revamp chart show dj duo jk and ...
# 1487       1590  weak dollar hits reuters revenues at media gro...
# 1488       1587  apple ipod family expands market apple has exp...
# 1489        538  santy worm makes unwelcome visit thousands of ...
#
#            Category
# 0          business
# 1          business
# 2          business
# 3              tech
# 4          business
# ...             ...
# 1485  entertainment
# 1486  entertainment
# 1487       business
# 1488           tech
# 1489           tech
#
# [1490 rows x 3 columns]

# %%
#Checking articles per class
df["Category"].value_counts()
# Out:
# sport            346
# business         336
# politics         274
# entertainment    273
# tech             261
# Name: Category, dtype: int64

# %%
#Text Processing
from nltk import word_tokenize
nltk.download('punkt')
from nltk.corpus import stopwords
nltk.download('stopwords')
stop_words = stopwords.words('english')
from nltk.stem import WordNetLemmatizer
nltk.download('wordnet') 
lemmatizer = WordNetLemmatizer() 

#Function to remove punctuations and stop words, lemmatization and tokenization
def text_processing(text):
    text_p = "".join([char for char in text if char not in string.punctuation])
    words = word_tokenize(text_p)
    filtered_tokens = [word for word in words if word not in stop_words]
    lemmatized_words = [lemmatizer.lemmatize(word) for word in filtered_tokens]
    return lemmatized_words
    
df_text = df["Text"].apply(lambda x: text_processing(x))
# Out:
# [nltk_data] Downloading package punkt to C:\Users\sana
# [nltk_data]     khan\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to C:\Users\sana
# [nltk_data]     khan\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to C:\Users\sana
# [nltk_data]     khan\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
df_text.head()
# Out:
# 0    [worldcom, exboss, launch, defence, lawyer, de...
# 1    [german, business, confidence, slide, german, ...
# 2    [bbc, poll, indicates, economic, gloom, citize...
# 3    [lifestyle, governs, mobile, choice, faster, b...
# 4    [enron, boss, 168m, payout, eighteen, former, ...
# Name: Text, dtype: object

# %%
df_class = df["Category"]
df_class.head()
# Out:
# 0    business
# 1    business
# 2    business
# 3        tech
# 4    business
# Name: Category, dtype: object

# %%
#Concating the Text and Category Columns(dataframes) to prepare training dataframe or training set
df_train = pd.concat([df_text, df_class], axis = 1)
df_train.head()
# Out:
#                                                 Text  Category
# 0  [worldcom, exboss, launch, defence, lawyer, de...  business
# 1  [german, business, confidence, slide, german, ...  business
# 2  [bbc, poll, indicates, economic, gloom, citize...  business
# 3  [lifestyle, governs, mobile, choice, faster, b...      tech
# 4  [enron, boss, 168m, payout, eighteen, former, ...  business

# %%
cores = multiprocessing.cpu_count()
print(cores)
# Counts the number of cores in a computer
# Out:
# 8

# %%
tweetText = df_train['Text']
print(tweetText)
# Out:
# 0       [worldcom, exboss, launch, defence, lawyer, de...
# 1       [german, business, confidence, slide, german, ...
# 2       [bbc, poll, indicates, economic, gloom, citize...
# 3       [lifestyle, governs, mobile, choice, faster, b...
# 4       [enron, boss, 168m, payout, eighteen, former, ...
#                               ...
# 1485    [double, eviction, big, brother, model, capric...
# 1486    [dj, double, act, revamp, chart, show, dj, duo...
# 1487    [weak, dollar, hit, reuters, revenue, medium, ...
# 1488    [apple, ipod, family, expands, market, apple, ...
# 1489    [santy, worm, make, unwelcome, visit, thousand...
# Name: Text, Length: 1490, dtype: object

# %%
# Training the Word2Vec model
t=time()
model = Word2Vec(tweetText, min_count=2,workers=7)       # Ignores all words with total absolute frequency lower than 2 and uses 7 worker threads to train the model
words =  model.wv.key_to_index                           

print('Time to train the model: {} mins'.format(round((time() - t) / 60, 2)))
# Out:
# INFO - 17:10:54: collecting all words and their counts
# INFO - 17:10:54: PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# INFO - 17:10:54: collected 24834 word types from a corpus of 327187 raw words and 1490 sentences
# INFO - 17:10:54: Creating a fresh vocabulary
# INFO - 17:10:54: Word2Vec lifecycle event {'msg': 'effective_min_count=2 retains 14942 unique words (60.16751228154949%% of original 24834, drops 9892)', 'datetime': '2021-11-08T17:10:54.524547', 'gensim': '4.1.2', 'python': '3.8.5 (default, Sep  3 2020, 21:29:08) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22000-SP0', 'event': 'prepare_vocab'}
# INFO - 17:10:54: Word2Vec lifecycle event {'msg': 'effective_min_count=2 leaves 317295 word corpus (96.97665249536198%% of original 327187, drops 9892)', 'datetime': '2021-11-08T17:10:54.525578', 'gensim': '4.1.2', 'python': '3.8.5 (default, Sep  3 2020, 21:29:08) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22000-SP0', 'event': 'prepare_vocab'}
# INFO - 17:10:54: deleting the raw counts dictionary of 24834 items
# INFO - 17:10:54: sample=0.001 downsamples 15 most-common words
# INFO - 17:10:54: Word2Vec lifecycle event {'msg': 'downsampling leaves estimated 309603.7181185053 word corpus (97.6%% of prior 317295)', 'datetime': '2021-11-08T17:10:54.649827', 'gensim': '4.1.2', 'python': '3.8.5 (default, Sep  3 2020, 21:29:08) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22000-SP0', 'event': 'prepare_vocab'}
# INFO - 17:10:54: estimated required memory for 14942 words and 100 dimensions: 19424600 bytes
# INFO - 17:10:54: resetting layer weights
# INFO - 17:10:54: Word2Vec lifecycle event {'update': False, 'trim_rule': 'None', 'datetime': '2021-11-08T17:10:54.807938', 'gensim': '4.1.2', 'python': '3.8.5 (default, Sep  3 2020, 21:29:08) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22000-SP0', 'event': 'build_vocab'}
# INFO - 17:10:54: Word2Vec lifecycle event {'msg': 'training model with 3 workers on 14942 vocabulary and 100 features, using sg=0 hs=0 sample=0.001 negative=5 window=5 shrink_windows=True', 'datetime': '2021-11-08T17:10:54.808977', 'gensim': '4.1.2', 'python': '3.8.5 (default, Sep  3 2020, 21:29:08) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22000-SP0', 'event': 'train'}
# INFO - 17:10:55: worker thread finished; awaiting finish of 2 more threads
# INFO - 17:10:55: worker thread finished; awaiting finish of 1 more threads
# INFO - 17:10:55: worker thread finished; awaiting finish of 0 more threads
# INFO - 17:10:55: EPOCH - 1 : training on 327187 raw words (309631 effective words) took 0.2s, 1605221 effective words/s
# INFO - 17:10:55: worker thread finished; awaiting finish of 2 more threads
# INFO - 17:10:55: worker thread finished; awaiting finish of 1 more threads
# INFO - 17:10:55: worker thread finished; awaiting finish of 0 more threads
# INFO - 17:10:55: EPOCH - 2 : training on 327187 raw words (309554 effective words) took 0.2s, 1523058 effective words/s
# INFO - 17:10:55: worker thread finished; awaiting finish of 2 more threads
# INFO - 17:10:55: worker thread finished; awaiting finish of 1 more threads
# INFO - 17:10:55: worker thread finished; awaiting finish of 0 more threads
# INFO - 17:10:55: EPOCH - 3 : training on 327187 raw words (309728 effective words) took 0.2s, 1596448 effective words/s
# INFO - 17:10:55: worker thread finished; awaiting finish of 2 more threads
# INFO - 17:10:55: worker thread finished; awaiting finish of 1 more threads
# INFO - 17:10:55: worker thread finished; awaiting finish of 0 more threads
# INFO - 17:10:55: EPOCH - 4 : training on 327187 raw words (309559 effective words) took 0.2s, 1469634 effective words/s
# INFO - 17:10:55: worker thread finished; awaiting finish of 2 more threads
# INFO - 17:10:55: worker thread finished; awaiting finish of 1 more threads
# INFO - 17:10:55: worker thread finished; awaiting finish of 0 more threads
# INFO - 17:10:55: EPOCH - 5 : training on 327187 raw words (309661 effective words) took 0.2s, 1541497 effective words/s
# INFO - 17:10:55: Word2Vec lifecycle event {'msg': 'training on 1635935 raw words (1548133 effective words) took 1.0s, 1510178 effective words/s', 'datetime': '2021-11-08T17:10:55.834837', 'gensim': '4.1.2', 'python': '3.8.5 (default, Sep  3 2020, 21:29:08) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22000-SP0', 'event': 'train'}
# INFO - 17:10:55: Word2Vec lifecycle event {'params': 'Word2Vec(vocab=14942, vector_size=100, alpha=0.025)', 'datetime': '2021-11-08T17:10:55.835838', 'gensim': '4.1.2', 'python': '3.8.5 (default, Sep  3 2020, 21:29:08) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22000-SP0', 'event': 'created'}
# Time to train the model: 0.02 mins

# %%
print(words)       #prints all the vocabulary found out in the word2vec model
# Out:
# {'said': 0, 'mr': 1, 'year': 2, 'would': 3, 'also': 4, 'new': 5, 'people': 6, 'u': 7, 'one': 8, 'could': 9, 'game': 10, 'time': 11, 'first': 12, 'last': 13, 'say': 14, 'two': 15, 'world': 16, 'film': 17, 'government': 18, 'uk': 19, 'make': 20, 'company': 21, 'firm': 22, 'get': 23, 'number': 24, 'service': 25, 'best': 26, 'told': 27, 'made': 28, 'country': 29, 'many': 30, 'take': 31, 'month': 32, 'like': 33, '000': 34, 'market': 35, 'three': 36, 'week': 37, 'player': 38, 'way
': 232, 'cup': 233, 'taking': 234, 'seen': 235, 'woman': 236, 'role': 237, 'china': 238, 'actor': 239, 'away': 240, 'although': 241, 'early': 242, 'foreign': 243, 'title': 244, 'saying': 245, 'lead': 246, 'champion': 247, 'level': 248, 'line': 249, 'programme': 250, 'run': 251, 'went': 252, 'recent': 253, 'due': 254, 'pay': 255, 'president': 256, 'far': 257, 'left': 258, 'microsoft': 259, 'house': 260, 'every': 261, 'le': 262, 'band': 263, 'dollar': 264, 'email': 265, 'lost': 266, 'research': 267, 'called': 268, 'data': 269, 'making': 270, 'card': 271, 'biggest': 272, 'secretary': 273, 'financial': 274, 'michael': 275, 'south': 276, 'half': 277, 'event': 278, 'season': 279, 'played': 280, 'mp': 281, 'held': 282, 'long': 283, 'become': 284, '20': 285, 'oil': 286, 'using': 287, 'important': 288, 'support': 289, 'hard': 290, ...

# %%
# Finding word Vectors
vector = model.wv['entertainment']
print(vector)
# Out:
# [-0.2319754   0.4373964   0.3081828   0.20914842 -0.05362097 -0.70766836
#  -0.09084617  0.93580574 -0.22394222 -0.25147    -0.07347605 -0.7065266
#  -0.11898592  0.41720116 -0.02581927 -0.3174657  -0.13080119 -0.47943214
#   0.1596204  -0.9931767   0.33016425  0.2776057   0.02142363 -0.0971847
#  -0.1366145   0.15079534 -0.16040218 -0.15704189 -0.34443024  0.07541261
#   0.30469948 -0.09794006  0.19442296 -0.20326497 -0.01473201  0.3660454
#   0.11356224 -0.28347522 -0.14557323 -0.7845251   0.04706049 -0.4899026
#  -0.17936523 -0.14666247  0.37373993 -0.37434885 -0.572218    0.21230896
#   0.33112538  0.5377251   0.11068539 -0.1979758  -0.1953409  -0.10825908
#  -0.24950066  0.24522915  0.22521502 -0.15483417 -0.5209057   0.25001556
#   0.18703018  0.3737981  -0.26700208  0.07536666 -0.6956297   0.3855386
#   0.08443395  0.35801092 -0.30445212  0.27930406 -0.2806987   0.39639232
#   0.39830917 -0.12235455  0.49675643  0.23217477 -0.01622148  0.01332388
#  -0.40230304  0.03690454 -0.07462896 -0.23640291 -0.16193318  0.608345
#   0.14903465 -0.0364947  -0.09711421  0.4400375   0.4495236   0.17482935
#   0.30089608  0.0754187   0.2317647   0.06605458  0.51035345  0.40176946
#   0.15741041 -0.5280053   0.1475887   0.16980544]

# %%
model.wv.most_similar(positive=["tech"])     #finds most similar words
# Out:
# [('operating', 0.9971630573272705),
#  ('buy', 0.997015655040741),
#  ('instead', 0.9963255524635315),
#  ('chinese', 0.9962673187255859),
#  ('large', 0.996232807636261),
#  ('improving', 0.9962231516838074),
#  ('amount', 0.9961767792701721),
#  ('telecom', 0.9961448311805725),
#  ('seeking', 0.9960784316062927),
#  ('area', 0.9960241913795471)]

# %%
model.wv.similarity('apple', 'ipod')         #finds similarity between the two words
# Out:
# 0.9966841
